# %% [markdown]
# <a href="https://colab.research.google.com/github/AnamKwon/Gwangju-Ai-center-Free-course_anam/blob/master/1%EC%A3%BC%EC%B0%A8%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##1주차 과제(5.21~27)
# * 언어분야
#  * 구글언어번역기
#
#    [google 번역](https://translate.google.com/)
#    ![image.png](data:image/png;base64,...)
#
# * 음성
#  * 구글음성인식 검색
#
#     [google](https://www.google.co.kr/)
#     ![image.png](data:image/png;base64,...)
#
# * 이미지
#  * 구글이미지검색
#
#     [google 이미지](https://www.google.co.kr/imghp?hl=ko)
#     ![image.png](data:image/png;base64,...)
#
# * 자율주행
#  * 현대자동차
#     [자율주행 로드맵](https://www.hyundai.co.kr/TechInnovation/Autonomous/Roadmap.hub)
#     ![image.png](data:image/png;base64,...)
